# %%
import pandas as pd
import cryptpandas as crp
from IPython.display import clear_output

# %%
password = input('Password? ')
clear_output()

# %%
filename = 'SMMIS data (1988-2000).crypt'

# %%
df = crp.read_encrypted(filename, password=password)
df.set_index('recordno', inplace=True)
df.head()
# Out:
#           hospital                  hospname    year      ed91  crstairs  \
# recordno
# 1.0            1.0  Edgware General Hospital  1988.0  02ARFE06       3.0
# 2.0            1.0  Edgware General Hospital  1988.0      None       NaN
# 3.0            1.0  Edgware General Hospital  1988.0  02ARFW11      -1.0
# 4.0            1.0  Edgware General Hospital  1988.0  02ARFA06      -1.0
# 5.0            1.0  Edgware General Hospital  1988.0      None       NaN
#
#           crsquint mhospnum  birthord  birthmth recstat  ...  mdest bornat  \
# recordno                                                 ...
# 1.0            5.0   121501       1.0      10.0       5  ...   None    NaN
# 2.0            NaN   222222       1.0       1.0       6  ...   None    NaN
# 3.0            3.0   422294       1.0       8.0       G  ...      T    NaN
# 4.0            2.0  B023774       1.0       6.0       H  ...      U    NaN
# 5.0            NaN  B114268       1.0      12.0       G  ...      U    NaN
#
# ...

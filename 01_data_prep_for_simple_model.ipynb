# %% [markdown]
# # Data cleaning for simple model

# %%
import cryptpandas as crp
import datetime as dt
import numpy as np
import pandas as pd

from IPython.display import clear_output
from utils.missing import replace_missing_values

# %% [markdown]
# ## Load files

# %%
impute_method = pd.read_csv('./data/missing_values_method.csv')

# %%
data_info = pd.read_csv('./data/SMMIS_fields.csv')
data_info.head()
# Out:
#    Field # Variable name  Base model                          Description  \
# 0        1      RECORDNO         NaN                 Oracle record number
# 1        2      HOSPITAL         NaN  SMMIS hospital code number of birth
# 2        3      HOSPNAME         1.0                        Hospital name
# 3        4          YEAR         NaN                       Year of record
# 4        5          ED91         NaN    Enumeration district of residence
#
#   Used in preliminary data (Y=yes, N=no) Field type  \
# 0                                      Y    Numeric
# 1                                      Y    Numeric
# 2                                      N      Label
# 3                                      Y    Numeric
# 4                                      N      Label
#
#   Criteria for inclusion in study Missing value criteria Discrepant values  \
# 0                             NaN                    NaN               NaN
# 1                             NaN                    NaN               NaN
# 2                             NaN                    NaN               NaN
# 3                             NaN                    NaN               NaN
# 4                             NaN                    NaN               NaN
#
#   Recoded variable name Recoded variable values
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4                   NaN                     NaN

# %%
password = input('Password? ')
clear_output()

# %%
filename = './data/SMMIS data (1988-2000).crypt'
data = crp.read_encrypted(filename, password=password)
data.set_index('recordno', inplace=True)

# Save unecrypted for inspection
sample = data.sample(100).T
sample.to_csv('./data/SMMIS_sample.csv')

# %%
# Remove data with no 5 min Apgar score
mask = data['apgar5'].notnull()
data = data[mask]

# %% [markdown]
# Filter data to fileds used in base model

# %%
mask = data_info['Base model'] == 1
fields = list(data_info['Variable name'][mask])
fields = [field.lower() for field in fields]
data = data[fields]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 511888 entries, 3.0 to 585291.0
# Data columns (total 19 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   hospname  511888 non-null  object
#  1   mdob      511700 non-null  object
#  2   ethnic    497690 non-null  object
#  3   parity    511798 non-null  float64
#  4   prevcaes  511798 non-null  float64
#  5   lperiod   488322 non-null  object
#  6   mheight   424598 non-null  float64
#  7   mweight   445826 non-null  float64
#  8   noscans   505133 non-null  float64
#  9   onsetla   511276 non-null  object
#  10  analab    504702 non-null  object
#  11  analdel   484892 non-null  object
#  12  methind   193427 non-null  object
#  13  pyrexia   510281 non-null  object
#  14  ctg       511000 non-null  object
#  15  meconium  511285 non-null  object
#  16  birthdat  511888 non-null  object
#  17  methdel   511880 non-null  object
#  18  apgar5    511888 non-null  float64
# dtypes: float64(6), object(13)
# memory usage: 78.1+ MB

# %%
# Format data values
cols = ['mdob','lperiod', 'birthdat']

for col in cols:
    data[col] = pd.to_datetime(data[col])

# %% [markdown]
# ## Replace missing values for selected fields

# %%
# Replace missing induction method with 'NA'
data['methind'] = replace_missing_values(data['methind'], 'NA')

# Replace missing hight and weight with zero
data['mweight'] = replace_missing_values(data['mweight'], 'zero')
data['mheight'] = replace_missing_values(data['mheight'], 'zero')
# Out:
# /home/michael/MK_Sync/intrapartum_risk_pilot/utils/missing.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s[missing] = 'NA'
# /home/michael/MK_Sync/intrapartum_risk_pilot/utils/missing.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s[missing] = 0
# /home/michael/MK_Sync/intrapartum_risk_pilot/utils/missing.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s[missing] = 0

# %%
# Keep complete data only
mask = data.isnull().sum(axis=1) == 0
data = data[mask]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 440300 entries, 4.0 to 585291.0
# Data columns (total 19 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   hospname  440300 non-null  object
#  1   mdob      440300 non-null  datetime64[ns]
#  2   ethnic    440300 non-null  object
#  3   parity    440300 non-null  float64
#  4   prevcaes  440300 non-null  float64
#  5   lperiod   440300 non-null  datetime64[ns]
#  6   mheight   440300 non-null  float64
#  7   mweight   440300 non-null  float64
#  8   noscans   440300 non-null  float64
#  9   onsetla   440300 non-null  object
#  10  analab    440300 non-null  object
#  11  analdel   440300 non-null  object
#  12  methind   440300 non-null  object
#  13  pyrexia   440300 non-null  object
#  14  ctg       440300 non-null  object
#  15  meconium  440300 non-null  object
#  16  birthdat  440300 non-null  datetime64[ns]
#  17  methdel   440300 non-null  object
#  18  apgar5    440300 non-null  float64
# dtypes: datetime64[ns](3), float64(6), object(10)
# memory usage: 67.2+ MB

# %% [markdown]
# ## Calculate required fields

# %%
# Calculate BMI
bmi = data['mweight'] / ((data['mheight']/100) ** 2)
bmi =  bmi.values.astype(int)

# Replace any BMI < 10 with zero
mask = bmi < 10
bmi[mask]= 0

data['bmi'] = bmi
data.drop(['mweight', 'mheight'], axis=1, inplace=True)

# %%
# Calculate age (years)
age = data['birthdat'] - data['mdob']
age = age.dt.days / 365
data ['age'] = age.values.astype(int)

# Calculate gestantion age (weeks)
gest = data['birthdat'] - data['lperiod']
gest = gest.dt.days / 7
data['gest'] = gest.values.astype(int)

# Remove dates
data.drop(['birthdat', 'mdob', 'lperiod'], axis=1, inplace=True)

# Remove any gestatton <20 weeks or >45 weeks
mask = (data['gest'] <= 45) & (data['gest'] >= 20)
data = data[mask]

# Remove parity > 10
mask = data['parity'] <= 10
data = data[mask]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 437181 entries, 4.0 to 585291.0
# Data columns (total 17 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   hospname  437181 non-null  object
#  1   ethnic    437181 non-null  object
#  2   parity    437181 non-null  float64
#  3   prevcaes  437181 non-null  float64
#  4   noscans   437181 non-null  float64
#  5   onsetla   437181 non-null  object
#  6   analab    437181 non-null  object
#  7   analdel   437181 non-null  object
#  8   methind   437181 non-null  object
#  9   pyrexia   437181 non-null  object
#  10  ctg       437181 non-null  object
#  11  meconium  437181 non-null  object
#  12  methdel   437181 non-null  object
#  13  apgar5    437181 non-null  float64
#  14  bmi       437181 non-null  int64
#  15  age       437181 non-null  int64
#  16  gest      437181 non-null  int64
# dtypes: float64(4), int64(3), object(10)
# memory usage: 60.0+ MB

# %%
# Remove subzero age and gestational age
mask = (data['age'] > 0) & (data['gest'] > 0)
data = data[mask]

# %%
# Reduce ethnicity
data['ethnic_white'] = data['ethnic'] == 'C'
data.drop('ethnic', axis=1, inplace=True)

# %%
# Randomise
data = data.sample(frac=1.0)

# %%
data.describe()
# Out:
#               parity       prevcaes        noscans         apgar5  \
# count  437181.000000  437181.000000  437181.000000  437181.000000
# mean        0.876458       0.084075       2.111823       9.493665
# std         1.077503       0.326890       1.336017       0.835762
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       1.000000       9.000000
# 50%         1.000000       0.000000       2.000000      10.000000
# 75%         1.000000       0.000000       3.000000      10.000000
# max        10.000000       7.000000       9.000000      10.000000
#
#                  bmi            age           gest
# count  437181.000000  437181.000000  437181.000000
# mean       18.943111      28.747064      39.409501
# std        10.397377       5.313596       2.238122
# min         0.000000      12.000000      20.000000
# 25%        19.000000      25.000000      38.000000
# 50%        22.000000      29.000000      40.000000
# 75%        25.000000      32.000000      41.000000
# max        77.000000      91.000000      45.000000

# %%
data.head().T
# Out:
# recordno              25060.0                  27731.0   \
# hospname      Ashford Hospital  West Middlesex Hospital
# parity                     1.0                      2.0
# prevcaes                   0.0                      0.0
# noscans                    1.0                      2.0
# onsetla                      S                        S
# analab                       N                       PI
# analdel                      N                        N
# methind                     NA                       NA
# pyrexia                      N                        N
# ctg                          N                        N
# meconium                     N                        N
# methdel                      S                        S
# apgar5                    10.0                      9.0
# bmi                         18                       20
# age                         27                       25
# gest                        38                       40
# ethnic_white             False                    False
#
# recordno                      343082.0             263709.0  \
# hospname      Watford General Hospital  St. Mary's Hospital
# parity                             0.0                  2.0
# prevcaes                           0.0                  0.0
# noscans                            5.0                  1.0
# onsetla                              I                    S
# analab                               E                    P
# analdel                              E                    P
# methind                             AO                   NA
# pyrexia                              N                    N
# ctg                                  N                    N
# meconium                             Y                    N
# methdel                              V                    S
# apgar5                            10.0                  9.0
# bmi                                 27                   33
# age                                 34                   29
# gest                                36                   26
# ethnic_white                     False                False
#
# recordno                     455131.0
# hospname      Barnet General Hospital
# parity                            1.0
# prevcaes                          0.0
# noscans                           2.0
# onsetla                             S
# analab                             IT
# analdel                            LT
# methind                            NA
# pyrexia                             N
# ctg                                 N
# meconium                            N
# methdel                             S
# apgar5                           10.0
# bmi                                25
# age                                37
# gest                               41
# ethnic_white                    False

# %%
data.to_csv('./data/data_for_model.csv', index=False)

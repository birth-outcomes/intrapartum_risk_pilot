# %%
import pandas as pd

# %%
data = pd.read_csv('./data/data_for_model.csv')

# %%
# Convert binary values to boolean

data['pyrexia'] = data['pyrexia'] == 'Y'
data['meconium'] = data['meconium'] == 'Y'

# %%
# Limit BMI 
mask = (data['bmi'] >= 15) & (data['bmi'] <= 50)
data = data[mask]

# Limit age 
mask = (data['age'] >= 15) & (data['age'] <= 45)
data = data[mask]

# %%
# Analgesics used

def check_analgesia(x, code):
    analgesics = list(x['analab'])
    for analgesic in list(x['analdel']):
        analgesics.extend(analgesic)
    return code in analgesics

analgesic_types = ['I', 'P', 'E', 'G', 'S', 'C', 'T', 'L', 'B', 'O']

for analgesic_type in analgesic_types:
    label = f'analgesia_{analgesic_type}'
    data[label] = data.apply(check_analgesia, axis=1, args=analgesic_type)

data.drop(['analab', 'analdel'], axis=1, inplace=True)

# %%
# Induction used

def check_induction(x, code):
    try:
        return code in list(x['methind'])
    except:
        return False

induction_types = ['A', 'O', 'P']

for induction_type in induction_types:
    label = f'induction_{induction_type}'
    data[label] = data.apply(check_induction, axis=1, args=induction_type)

data.drop(['methind'], axis=1, inplace=True)

# %%
# CTG
ctg = pd.get_dummies(data['ctg'],prefix='ctg')
data = pd.concat([data, ctg], axis=1)
data.drop(['ctg'], axis=1, inplace=True)

# %%
# Delivery
delivery = pd.get_dummies(data['methdel'],prefix='delivery')
data = pd.concat([data, delivery], axis=1)
data.drop(['methdel'], axis=1, inplace=True)

# %%
# Hospital
hospital = pd.get_dummies(data['hospname'],prefix='hospital')
data = pd.concat([data, hospital], axis=1)
data.drop(['hospname'], axis=1, inplace=True)

# %%
# Labour onset
onset = pd.get_dummies(data['onsetla'],prefix='onset')
data = pd.concat([data, onset], axis=1)
data.drop(['onsetla'], axis=1, inplace=True)

# %%
# Change types
data['parity'] = data['parity'].astype(int)
data['prevcaes'] = data['prevcaes'].astype(int)
data['noscans'] = data['noscans'].astype(int)
data['apgar5'] = data['apgar5'].astype(int)
for col in list(data):
    if col[0:3] == 'ctg':
        data[col] = data[col].astype(bool)
for col in list(data):
    if col[0:8] == 'delivery':
        data[col] = data[col].astype(bool)
for col in list(data):
    if col[0:8] == 'hospital':
        data[col] = data[col].astype(bool)
for col in list(data):
    if col[0:5] == 'onset':
        data[col] = data[col].astype(bool)

# %%
data.head().T
# Out:
#                                                0      1      2      3      4
# parity                                         1      2      0      2      1
# prevcaes                                       0      0      0      0      0
# noscans                                        1      2      5      1      2
# pyrexia                                    False  False  False  False  False
# meconium                                   False  False   True  False  False
# apgar5                                        10      9     10      9     10
# bmi                                           18     20     27     33     25
# age                                           27     25     34     29     37
# gest                                          38     40     36     26     41
# ethnic_white                               False  False  False  False  False
# analgesia_I                                False   True  False  False   True
# analgesia_P                                False   True  False   True  False
# analgesia_E                                False  False   True  False  False
# analgesia_G                                False  False  False  False  False
# analgesia_S                                False  False  False  False  False
# analgesia_C                                False  False  False  False  False
# analgesia_T                                False  False  False  False   True
# analgesia_L                                False  False  False  False   True
# analgesia_B                                False  False  False  False  False
# analgesia_O                                False  False  False  False  False
# induction_A                                False  False   True  False  False
# induction_O                                False  False   True  False  False
# induction_P                                False  False  False  False  False
# ctg_A                                      False  False  False  False  False
# ctg_N                                       True   True   True   True   True
# ctg_Z                                      False  False  False  False  False
# delivery_A                                 False  False  False  False  False
# delivery_B                                 False  False  False  False  False
# delivery_C                                 False  False  False  False  False
# delivery_E                                 False  False  False  False  False
# delivery_L                                 False  False  False  False  False
# delivery_O                                 False  False  False  False  False
# delivery_R                                 False  False  False  False  False
# delivery_S                                  True   True  False   True   True
# delivery_V                                 False  False   True  False  False
# hospital_Ashford Hospital                   True  False  False  False  False
# hospital_Barnet General Hospital           False  False  False  False   True
# hospital_Bedford Hospital                  False  False  False  False  False
# hospital_Central Middlesex Hospital        False  False  False  False  False
# hospital_Chelsea and Westminster Hospital  False  False  False  False  False
# hospital_Ealing Hospital                   False  False  False  False  False
# hospital_Edgware General Hospital          False  False  False  False  False
# hospital_Hemel Hempstead Hospital          False  False  False  False  False
# hospital_Hillingdon Hospital               False  False  False  False  False
# hospital_Lister Hospital                   False  False  False  False  False
# hospital_Luton and Dunstable Hospital      False  False  False  False  False
# hospital_Northwick Park Hospital           False  False  False  False  False
# hospital_QEII Hospital                     False  False  False  False  False
# hospital_St. Albans Hospital               False  False  False  False  False
# hospital_St. Mary's Hospital               False  False  False   True  False
# hospital_Watford General Hospital          False  False   True  False  False
# hospital_West London Hospital              False  False  False  False  False
# hospital_West Middlesex Hospital           False   True  False  False  False
# hospital_Westminster  Hospital             False  False  False  False  False
# onset_E                                    False  False  False  False  False
# onset_I                                    False  False   True  False  False
# onset_N                                    False  False  False  False  False
# onset_S                                     True   True  False   True   True

# %%
data.to_csv('./data/processed_data_for_model_one_hot.csv', index=False)

# %% [markdown]
# ## Descriptive analysis of data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.ticker import ScalarFormatter

# %%
data = pd.read_csv('./data/data_for_model.csv')

# %%
list(data)
# Out:
# ['hospname',
#  'parity',
#  'prevcaes',
#  'noscans',
#  'onsetla',
#  'analab',
#  'analdel',
#  'methind',
#  'pyrexia',
#  'ctg',
#  'meconium',
#  'methdel',
#  'apgar5',
#  'bmi',
#  'age',
#  'gest',
#  'ethnic_white']

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot()
ax.hist(data['apgar5'], bins=range(11))
ax.set_yscale('log')
ax.grid(axis='y')
ax.set_xlabel('5min APGAR')
ax.set_ylabel('Count')

# Label axis using non-log numbers
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())

plt.show()
